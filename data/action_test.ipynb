# %%
import pandas as pd
import random
import itertools

# %%
df = pd.read_csv('key_action.csv').drop(['tags','priority'],axis=1)
df = df.rename({'name':'action_name'},axis=1)

# %%
df
# Out:
#              module          action_name          entities  \
# 0             basic                 rest              char
# 1             basic                relax              char
# 2             basic               eating              char
# 3             basic       training_alone              char
# 4          relation               murder        char,char2
# 5          relation              beat_up        char,char2
# 6          relation               poison        char,char2
# 7          relation             say_love   char,char2,item
# 8          relation       say_friendship   char,char2,item
# 9          relation                 duel        char,char2
# 10         relation  worsen_relationship  char,char2,char3
# 11         relation  better_relationship  char,char2,char3
# 12         relation           kill_frame  char,char2,char3
# 13         relation         give_present   char,char2,item
# 14         relation                steal        char,char2
# 15         relation                 heal        char,char2
# 16         relation    training_together        char,char2
# 17        room_shop                  buy         char,item
# 18        room_shop           steal_shop         char,item
# 19        room_shop        threaten_item   char,char2,item
# 20        room_shop                 sell         char,item
# 21  room_restaurant            eat_alone              char
# 22  room_restaurant         eat_together        char,char2
# 23  room_restaurant         poison_frame  char,char2,char3
# 24  room_restaurant    poison_restaurant        char,char2
# 25  room_restaurant            buy_later              char
# 26      room_casino     gambling_serious              char
# 27      room_casino         casino_cheat        char,char2
# 28      room_casino       gambling_relax              char
# 29              npc         befriend_npc              char
# 30              npc       get_rid_of_npc              char
# 31              npc             kill_npc              char
# 32              npc        assign_murder        char,char2
# 33              npc           get_reward              char
# 34      npc_trainer   pay_trainer_attack        char,char2
# 35      npc_trainer     training_trainer              char
# 36      npc_trainer    train_bad_someone        char,char2
# 37     danger_virus       create_vaccine              char
# 38     danger_virus           quarantine              char
# 39     danger_virus  quarantine_everyone        char,char2
# 40     danger_virus       infect_someone        char,char2
#
#                   requires altruism ambition consents
# 0                   health     > -5     <= 2     char
# 1                     book     > -5     <= 2     char
# 2                     food     > -5     <= 2     char
# 3                   health     > -5     >= 2     char
# 4                   danger    <= -2      > 4     char
# 5                   danger    <= -1      > 3     char
# 6     poison,blocked_char2    <= -2      > 2     char
# 7       item,blocked_char2     >= 2      > 3     char
# 8       item,blocked_char2     >= 2      > 2     char
# 9   danger, relation_char2     >= 1      > 3     char
# 10          relation_char2    <= -1      > 1     char
# 11          relation_char2     >= 1      > 1     char
# 12                  danger    <= -2      > 4     char
# 13                    item     >= 1      > 2     char
# 14           blocked_char2    <= -1      > 2     char
# 15                  poison     >= 1      > 2     char
# 16          relation_char2     >= 1      > 2     char
# 17                   money     > -5      < 4     char
# 18                  health      < 0      > 2     char
# 19                  danger      < 0      > 3     char
# 20                    item     > -5      < 4     char
# 21                   money     > -5      < 4     char
# 22   money, relation_char2      > 1      < 4     char
# 23   money, relation_char2    <= -2     >= 4     char
# 24   money, relation_char2    <= -2      > 3     char
# 25                   money     > -5      < 3     char
# 26                   money     > -5      > 3     char
# 27                  danger    <= -1     >= 3     char
# 28                   money     > -5      > 1     char
# 29                    food     >= 2     >= 2     char
# 30                  poison      < 1     >= 3     char
# 31                  weapon    >= -2     >= 4     char
# 32                   money    >= -2     >= 3     char
# 33                    food     <= 1     >= 1     char
# 34                   money    >= -2      > 1     char
# 35                   money     > -5     >= 2     char
# 36                   money    <= -1     >= 3     char
# 37                  poison     >= 1      > 2     char
# 38                  health     > -5      > 0     char
# 39                  danger     >= 2      > 2     char
# 40           blocked_char2     >= 1      > 2     char

# %%
modules = list(set(df.module.values))
print(modules)

modules_advanced = [x for x in modules if x not in ['basic','relation']]
print(modules_advanced)
# Out:
# ['basic', 'npc_trainer', 'danger_virus', 'relation', 'room_restaurant', 'room_casino', 'room_shop', 'npc']
# ['npc_trainer', 'danger_virus', 'room_restaurant', 'room_casino', 'room_shop', 'npc']

# %%
dic_key = {i:0 for i in itertools.product([-2,-1,0,1,2],[4,3,2,1,0])}

chosen_actions = []

# %%
dic_key
# Out:
# {(-2, 4): 0,
#  (-2, 3): 0,
#  (-2, 2): 0,
#  (-2, 1): 0,
#  (-2, 0): 0,
#  (-1, 4): 0,
#  (-1, 3): 0,
#  (-1, 2): 0,
#  (-1, 1): 0,
#  (-1, 0): 0,
#  (0, 4): 0,
#  (0, 3): 0,
#  (0, 2): 0,
#  (0, 1): 0,
#  (0, 0): 0,
#  (1, 4): 0,
#  (1, 3): 0,
#  (1, 2): 0,
#  (1, 1): 0,
#  (1, 0): 0,
#  (2, 4): 0,
#  (2, 3): 0,
#  (2, 2): 0,
#  (2, 1): 0,
#  (2, 0): 0}

# %%
main_module = random.choice(modules_advanced)
print(main_module)
# Out:
# room_shop

# %%
def check_range(val, min, max):
    
    sign, num = val.split(' ')
    l  = [] 

    if sign == '>':
        l= ([i for i in range(int(num)+1, max+1)]  )
    elif sign == '>=':
        l = ([i for i in range(int(num), max+1)])    
    elif sign == '<':
        l=  [i for i in range(min,int(num))]
    elif sign == '<=':
        l= [i for i in range(min,int(num)+1)]
    
    return l

# %%
for index, row in df[df.module == main_module].iterrows():
    chosen_actions.append(row['action_name'])
    
    altruism_val = check_range(row['altruism'],-2,2)
    ambition_val = check_range(row['ambition'],0,4)
    
    comb = itertools.product(altruism_val,ambition_val)
    for i in comb:
        if i in dic_key.keys():
            
            dic_key[i] = 1

# %%
print([ i for i in dic_key.keys()])
# Out:
# [(-2, 4), (-2, 3), (-2, 2), (-2, 1), (-2, 0), (-1, 4), (-1, 3), (-1, 2), (-1, 1), (-1, 0), (0, 4), (0, 3), (0, 2), (0, 1), (0, 0), (1, 4), (1, 3), (1, 2), (1, 1), (1, 0), (2, 4), (2, 3), (2, 2), (2, 1), (2, 0)]

# %%
while 0 in dic_key.values():
    random_idx = random.randint(0,len(df))
    row = df.iloc[random_idx]

    altruism_val = check_range(row['altruism'],-2,2)
    ambition_val = check_range(row['ambition'],0,4)
    
    comb = itertools.product(altruism_val,ambition_val)
    for i in comb:
        
        if i in dic_key.keys():
            
            if dic_key[i] == 0:
                chosen_actions.append(row['action_name'])
                dic_key[i] = 1

chosen_actions= list(set(chosen_actions))

# %%
print(chosen_actions)
print(dic_key)
# Out:
# ['buy', 'say_love', 'threaten_item', 'steal_shop', 'sell', 'training_trainer']
# {(-2, 4): 1, (-2, 3): 1, (-2, 2): 1, (-2, 1): 1, (-2, 0): 1, (-1, 4): 1, (-1, 3): 1, (-1, 2): 1, (-1, 1): 1, (-1, 0): 1, (0, 4): 1, (0, 3): 1, (0, 2): 1, (0, 1): 1, (0, 0): 1, (1, 4): 1, (1, 3): 1, (1, 2): 1, (1, 1): 1, (1, 0): 1, (2, 4): 1, (2, 3): 1, (2, 2): 1, (2, 1): 1, (2, 0): 1}

# %%
def key_action_to_text(row):
    entities = ""
    for ent in row.entities.split(','):
        
        if 'char' in ent:
            entities = entities + ent + ":character,"
        elif 'item' in ent:
            entities = entities + ent + ":item,"
    entities = entities.rstrip(',')

    req = ""
    items = ['food', 'weapon', 'book', 'poison', 'money' ,'item']
    for r in row.requires.split(','):
        if 'char2' in row.entities:
             req = req +'char!=char2 &'
        if 'char3' in row.entities:
             req = req +'char!=char3 &' +'char2!=char3 &'

        if r in items:
            req = req + "has_item(char)==" + r + " &"
        elif 'relation' in r:
            req = req + "relation(char2,char) > 0  &"
        elif 'health' in r:
            req = req + "health(char) > 0  &"
        elif 'blocked' in r:
            req = req + "blocked(char2) &"
        elif 'danger' in r:
            req = req + "danger(char) >= danger(char2) &"
    req = req.rstrip('&')


    sat = "if ("
    sat = sat + 'altruism(char) ' + row.altruism
    sat = sat + ' & ambition(char) ' + row.ambition
    sat += ") \n            satisfaction(char) = satisfaction(char) + 1 "

    text= f"""
    action {row.action_name}({entities}) {{
        precondition:
    
            {req}
            ;
        effect:
        {sat}
            ;
        consenting: {row.consents};
    }};

    """
    return text

# %%
text="""

type item;


//### Properties:
property satisfaction(char: character) : number; // Satisfaction level of each character
property altruism(char: character) : number; // Altruism level of each character (-3 to 3)
property ambition(char: character) : number; // Ambition level of each character (-3 to 3)
property desperation(char: character) : number; // Ambition level of each character (-3 to 3)
property max_desp(char: character) : number; // Ambition level of each character (-3 to 3)
property has_item(char: character) : item; 
property danger(char: character) : number; 
property health(char: character) : number; 
property blocked(char: character) : boolean; 

property relation(char: character, other: character) : number; // Relationship liking level between characters (-3 to 3)

entity mc : character;
entity actress : character;
entity actor : character;
entity food : item;
entity weapon : item;
entity book : item;
entity poison : item;
entity money : item;


health(mc) = 5;
health(actress) = 5;
health(actor) = 5;

ambition(mc) = {};
altruism(mc) = {};


""".format(5,-2)


df_chosen = df[df.action_name.isin(chosen_actions) ]
for index, row in df_chosen.iterrows():
    text = text + key_action_to_text(row) + "\n"

# %%
print(text)
# Out:
# type item;
#
#
# //### Properties:
# property satisfaction(char: character) : number; // Satisfaction level of each character
# property altruism(char: character) : number; // Altruism level of each character (-3 to 3)
# property ambition(char: character) : number; // Ambition level of each character (-3 to 3)
# property desperation(char: character) : number; // Ambition level of each character (-3 to 3)
# property max_desp(char: character) : number; // Ambition level of each character (-3 to 3)
# property has_item(char: character) : item;
# property danger(char: character) : number;
# property health(char: character) : number;
# property blocked(char: character) : boolean;
#
# property relation(char: character, other: character) : number; // Relationship liking level between characters (-3 to 3)
#
# entity mc : character;
# entity actress : character;
# entity actor : character;
# entity food : item;
# entity weapon : item;
# entity book : item;
# entity poison : item;
# entity money : item;
#
#
# health(mc) = 5;
# health(actress) = 5;
# health(actor) = 5;
#
# ambition(mc) = 5;
# altruism(mc) = -2;
#
#
#
#     action say_love(char:character,char2:character,item:item) {
#         precondition:
#
#             char!=char2 &has_item(char)==item &char!=char2 &blocked(char2)
#             ;
#         effect:
#         if (altruism(char) >= 2 & ambition(char) > 3)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action buy(char:character,item:item) {
#         precondition:
#
#             has_item(char)==money
#             ;
#         effect:
#         if (altruism(char) > -5 & ambition(char) < 4)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action steal_shop(char:character,item:item) {
#         precondition:
#
#             health(char) > 0
#             ;
#         effect:
#         if (altruism(char) < 0 & ambition(char) > 2)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action threaten_item(char:character,char2:character,item:item) {
#         precondition:
#
#             char!=char2 &danger(char) >= danger(char2)
#             ;
#         effect:
#         if (altruism(char) < 0 & ambition(char) > 3)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action sell(char:character,item:item) {
#         precondition:
#
#             has_item(char)==item
#             ;
#         effect:
#         if (altruism(char) > -5 & ambition(char) < 4)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action training_trainer(char:character) {
#         precondition:
#
#             has_item(char)==money
#             ;
#         effect:
#         if (altruism(char) > -5 & ambition(char) >= 2)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };

# %%
df_actions = pd.read_csv('actions.csv').drop(['tags','priority'],axis=1)

# %%
df_actions
# Out:
#    module                action_name          entities  \
# 0   basic        take_care_of_myself              char
# 1   basic                      fight        char;char2
# 2   basic               train_danger              char
# 3   basic                 steal_item   char;char2;item
# 4   basic                   beg_item   char;char2;item
# 5   basic                  take_item   char;char2;item
# 6   basic                  give_item   char;char2;item
# 7   basic             poison_lightly        char;char2
# 8   basic               heal_someone        char;char2
# 9   basic       take_care_of_someone        char;char2
# 10  basic              buy_attention        char;char2
# 11  basic         threaten_attention        char;char2
# 12  basic  beg_for_someone_attention  char;char2;char3
# 13  basic          beg_for_attention        char;char2
# 14  basic                   get_item         char;item
#
#                                              requires  \
# 0               has_item(char)==poison;health(char)<0
# 1       char!=char2;danger(char) >0;altruism(char) <0
# 2                                     danger(char) <0
# 3                      char!=char2;altruism(char)  <0
# 4   char!=char2;relation(char2,char) >0 ; ambition...
# 5   char!=char2;danger(char) >0;altruism(char)  <0...
# 6                    char!=char2;has_item(char)==item
# 7   char!=char2;has_item(char)==poison;altruism(ch...
# 8                  char!=char2;has_item(char)==poison
# 9                         char!=char2;health(char) <0
# 10                  char!=char2;has_item(char)==money
# 11                       char!=char2;danger(char) > 0
# 12  char!=char2;relation(char3,char2) > 0; ambitio...
# 13  char!=char2;relation(char2,char) >0; ambition(...
# 14                                    health(char) >0
#
#                                               effects    consents
# 0      danger(char) = danger(char)+ 1; !blocked(char)        char
# 1   danger(char2) =danger(char2) - 1 ;blocked(char...        char
# 2                     danger(char) =danger(char)  + 1        char
# 3               has_item(char)=item;has_item(char2)=?        char
# 4               has_item(char)=item;has_item(char2)=?        char
# 5       has_item(char)=item;relation(char2,char) = -2        char
# 6   has_item(char2)=item;has_item(char)=?;relation...        char
# 7   has_item(char)=?;danger(char2) =danger(char2) ...        char
# 8            !blocked(char2);relation(char2,char) = 1        char
# 9            !blocked(char2);relation(char2,char) = 1        char
# 10                    blocked(char2);has_item(char)=?        char
# 11           blocked(char2);relation(char2,char) = -1        char
# 12                                     blocked(char3)  char,char2
# 13                                     blocked(char2)  char,char2
# 14                                has_item(char)=item        char

# %%
def action_to_text(row):
    entities = ""
    for ent in row.entities.split(';'):
        
        if 'char' in ent:
            entities = entities + ent + ":character,"
        elif 'item' in ent:
            entities = entities + ent + ":item,"
    entities = entities.rstrip(',')

    req = ""
    
    for r in row.requires.split(';'):
        
        req = req +  r + " & "
    req = req.rstrip('& ')

    eff =''
    for e in row.effects.split(';'):
        
        eff = eff +  e + " & "
    eff = eff.rstrip('& ')

    text= f"""
    action {row.action_name}({entities}) {{
        precondition:
            {req}
            ;
        effect:
        {eff}
            ;
        consenting: {row.consents};
    }};

    """
    return text

# %%
for index, row in df_actions.iterrows():
    text = text + action_to_text(row) + "\n"

# %%
text= text + """
utility():
    satisfaction(mc);

utility(mc):
    satisfaction(mc);

utility(actress):
    satisfaction(actress);

utility(actor):
    satisfaction(actor);


"""

# %%
print(text)
# Out:
# type item;
#
#
# //### Properties:
# property satisfaction(char: character) : number; // Satisfaction level of each character
# property altruism(char: character) : number; // Altruism level of each character (-3 to 3)
# property ambition(char: character) : number; // Ambition level of each character (-3 to 3)
# property desperation(char: character) : number; // Ambition level of each character (-3 to 3)
# property max_desp(char: character) : number; // Ambition level of each character (-3 to 3)
# property has_item(char: character) : item;
# property danger(char: character) : number;
# property health(char: character) : number;
# property blocked(char: character) : boolean;
#
# property relation(char: character, other: character) : number; // Relationship liking level between characters (-3 to 3)
#
# entity mc : character;
# entity actress : character;
# entity actor : character;
# entity food : item;
# entity weapon : item;
# entity book : item;
# entity poison : item;
# entity money : item;
#
#
# health(mc) = 5;
# health(actress) = 5;
# health(actor) = 5;
#
# ambition(mc) = 5;
# altruism(mc) = -2;
#
#
#
#     action say_love(char:character,char2:character,item:item) {
#         precondition:
#
#             char!=char2 &has_item(char)==item &char!=char2 &blocked(char2)
#             ;
#         effect:
#         if (altruism(char) >= 2 & ambition(char) > 3)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action buy(char:character,item:item) {
#         precondition:
#
#             has_item(char)==money
#             ;
#         effect:
#         if (altruism(char) > -5 & ambition(char) < 4)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action steal_shop(char:character,item:item) {
#         precondition:
#
#             health(char) > 0
#             ;
#         effect:
#         if (altruism(char) < 0 & ambition(char) > 2)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action threaten_item(char:character,char2:character,item:item) {
#         precondition:
#
#             char!=char2 &danger(char) >= danger(char2)
#             ;
#         effect:
#         if (altruism(char) < 0 & ambition(char) > 3)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action sell(char:character,item:item) {
#         precondition:
#
#             has_item(char)==item
#             ;
#         effect:
#         if (altruism(char) > -5 & ambition(char) < 4)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action training_trainer(char:character) {
#         precondition:
#
#             has_item(char)==money
#             ;
#         effect:
#         if (altruism(char) > -5 & ambition(char) >= 2)
#             satisfaction(char) = satisfaction(char) + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action take_care_of_myself(char:character) {
#         precondition:
#             has_item(char)==poison & health(char)<0
#             ;
#         effect:
#         danger(char) = danger(char)+ 1 &  !blocked(char)
#             ;
#         consenting: char;
#     };
#
#
#
#     action fight(char:character,char2:character) {
#         precondition:
#             char!=char2 & danger(char) >0 & altruism(char) <0
#             ;
#         effect:
#         danger(char2) =danger(char2) - 1  & blocked(char2) & relation(char2,char) = -1
#             ;
#         consenting: char;
#     };
#
#
#
#     action train_danger(char:character) {
#         precondition:
#             danger(char) <0
#             ;
#         effect:
#         danger(char) =danger(char)  + 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action steal_item(char:character,char2:character,item:item) {
#         precondition:
#             char!=char2 & altruism(char)  <0
#             ;
#         effect:
#         has_item(char)=item & has_item(char2)=?
#             ;
#         consenting: char;
#     };
#
#
#
#     action beg_item(char:character,char2:character,item:item) {
#         precondition:
#             char!=char2 & relation(char2,char) >0  &  ambition(char)  <2
#             ;
#         effect:
#         has_item(char)=item & has_item(char2)=?
#             ;
#         consenting: char;
#     };
#
#
#
#     action take_item(char:character,char2:character,item:item) {
#         precondition:
#             char!=char2 & danger(char) >0 & altruism(char)  <0 & ambition(char)  >1
#             ;
#         effect:
#         has_item(char)=item & relation(char2,char) = -2
#             ;
#         consenting: char;
#     };
#
#
#
#     action give_item(char:character,char2:character,item:item) {
#         precondition:
#             char!=char2 & has_item(char)==item
#             ;
#         effect:
#         has_item(char2)=item & has_item(char)=? & relation(char2,char) = -1
#             ;
#         consenting: char;
#     };
#
#
#
#     action poison_lightly(char:character,char2:character) {
#         precondition:
#             char!=char2 & has_item(char)==poison & altruism(char) <0
#             ;
#         effect:
#         has_item(char)=? & danger(char2) =danger(char2) - 1 & blocked(char2)
#             ;
#         consenting: char;
#     };
#
#
#
#     action heal_someone(char:character,char2:character) {
#         precondition:
#             char!=char2 & has_item(char)==poison
#             ;
#         effect:
#         !blocked(char2) & relation(char2,char) = 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action take_care_of_someone(char:character,char2:character) {
#         precondition:
#             char!=char2 & health(char) <0
#             ;
#         effect:
#         !blocked(char2) & relation(char2,char) = 1
#             ;
#         consenting: char;
#     };
#
#
#
#     action buy_attention(char:character,char2:character) {
#         precondition:
#             char!=char2 & has_item(char)==money
#             ;
#         effect:
#         blocked(char2) & has_item(char)=?
#             ;
#         consenting: char;
#     };
#
#
#
#     action threaten_attention(char:character,char2:character) {
#         precondition:
#             char!=char2 & danger(char) > 0
#             ;
#         effect:
#         blocked(char2) & relation(char2,char) = -1
#             ;
#         consenting: char;
#     };
#
#
#
#     action beg_for_someone_attention(char:character,char2:character,char3:character) {
#         precondition:
#             char!=char2 & relation(char3,char2) > 0 &  ambition(char) <2
#             ;
#         effect:
#         blocked(char3)
#             ;
#         consenting: char,char2;
#     };
#
#
#
#     action beg_for_attention(char:character,char2:character) {
#         precondition:
#             char!=char2 & relation(char2,char) >0 &  ambition(char) <2
#             ;
#         effect:
#         blocked(char2)
#             ;
#         consenting: char,char2;
#     };
#
#
#
#     action get_item(char:character,item:item) {
#         precondition:
#             health(char) >0
#             ;
#         effect:
#         has_item(char)=item
#             ;
#         consenting: char;
#     };
#
#
#
# utility():
#     satisfaction(mc);
#
# utility(mc):
#     satisfaction(mc);
#
# utility(actress):
#     satisfaction(actress);
#
# utility(actor):
#     satisfaction(actor);

# %%
file1 = open("E:\\Praca_magisterska\\narrative_system\\lib\\test1.txt", "w") 
file1.write(text)


file1.close()

# %%
#cały plik - zawsze ktoś ma item
#triggery,w tym danger
